# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
plt.close('all')

# %%
movies = pd.read_csv(r"C:\Users\Eric\Documents\EECS 731\Project 3\data\ml-latest-small\ml-latest-small\movies.csv")

# %%
print("Column names: %s" % str(movies.columns))
# Out:
# Column names: Index(['movieId', 'title', 'genres'], dtype='object')

# %%
ratings = pd.read_csv(r"C:\Users\Eric\Documents\EECS 731\Project 3\data\ml-latest-small\ml-latest-small\ratings.csv")

# %%
print("Column names: %s" % str(ratings.columns))
# Out:
# Column names: Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
links = pd.read_csv(r"C:\Users\Eric\Documents\EECS 731\Project 3\data\ml-latest-small\ml-latest-small\links.csv")

# %%
print("Column names: %s" % str(links.columns))
# Out:
# Column names: Index(['movieId', 'imdbId', 'tmdbId'], dtype='object')

# %%
tags = pd.read_csv(r"C:\Users\Eric\Documents\EECS 731\Project 3\data\ml-latest-small\ml-latest-small\tags.csv")

# %%
print("Column names: %s" % str(tags.columns))
# Out:
# Column names: Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
ratings["rating"].mean()
# Out:
# 3.501556983616962

# %%
ratings[ratings.movieId == 1]
# Out:
#        userId  movieId  rating   timestamp
# 0           1        1     4.0   964982703
# 516         5        1     4.0   847434962
# 874         7        1     4.5  1106635946
# 1434       15        1     2.5  1510577970
# 1667       17        1     4.5  1305696483
# ...       ...      ...     ...         ...
# 97364     606        1     2.5  1349082950
# 98479     607        1     4.0   964744033
# 98666     608        1     2.5  1117408267
# 99497     609        1     3.0   847221025
# 99534     610        1     5.0  1479542900
#
# [215 rows x 4 columns]

# %%
ratings[['rating']].where(ratings[['movieId']].values == 1).stack().mean()
# Out:
# 3.9209302325581397

# %%
movies.insert(1, "AvgRating", 0.0)

# %%
movies
# Out:
#       movieId  AvgRating                                      title  \
# 0           1        0.0                           Toy Story (1995)
# 1           2        0.0                             Jumanji (1995)
# 2           3        0.0                    Grumpier Old Men (1995)
# 3           4        0.0                   Waiting to Exhale (1995)
# 4           5        0.0         Father of the Bride Part II (1995)
# ...       ...        ...                                        ...
# 9737   193581        0.0  Black Butler: Book of the Atlantic (2017)
# 9738   193583        0.0               No Game No Life: Zero (2017)
# 9739   193585        0.0                               Flint (2017)
# 9740   193587        0.0        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        0.0        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 4 columns]

# %%
def calculate_avg(row):
    return ratings[['rating']].where(ratings[['movieId']].values == row['movieId']).stack().mean()

# %%
movies['AvgRating'] = movies.apply(calculate_avg, axis=1)
movies
# Out:
#       movieId  AvgRating                                      title  \
# 0           1   3.920930                           Toy Story (1995)
# 1           2   3.431818                             Jumanji (1995)
# 2           3   3.259615                    Grumpier Old Men (1995)
# 3           4   2.357143                   Waiting to Exhale (1995)
# 4           5   3.071429         Father of the Bride Part II (1995)
# ...       ...        ...                                        ...
# 9737   193581   4.000000  Black Butler: Book of the Atlantic (2017)
# 9738   193583   3.500000               No Game No Life: Zero (2017)
# 9739   193585   3.500000                               Flint (2017)
# 9740   193587   3.500000        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609   4.000000        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 4 columns]

# %%
movies.insert(1, "NumRating", 0)

# %%
movies
# Out:
#       movieId  NumRating  AvgRating  \
# 0           1          0   3.920930
# 1           2          0   3.431818
# 2           3          0   3.259615
# 3           4          0   2.357143
# 4           5          0   3.071429
# ...       ...        ...        ...
# 9737   193581          0   4.000000
# 9738   193583          0   3.500000
# 9739   193585          0   3.500000
# 9740   193587          0   3.500000
# 9741   193609          0   4.000000
#
#                                           title  \
# 0                              Toy Story (1995)
# 1                                Jumanji (1995)
# 2                       Grumpier Old Men (1995)
# 3                      Waiting to Exhale (1995)
# 4            Father of the Bride Part II (1995)
# ...                                         ...
# 9737  Black Butler: Book of the Atlantic (2017)
# 9738               No Game No Life: Zero (2017)
# 9739                               Flint (2017)
# 9740        Bungo Stray Dogs: Dead Apple (2018)
# 9741        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 5 columns]

# %%
def calculate_numRatings(row):
    return ratings[['rating']].where(ratings[['movieId']].values == row['movieId']).stack().nunique()

# %%
movies['NumRating'] = movies.apply(calculate_numRatings, axis=1)
movies
# Out:
#       movieId  NumRating  AvgRating  \
# 0           1          9   3.920930
# 1           2         10   3.431818
# 2           3          9   3.259615
# 3           4          4   2.357143
# 4           5          9   3.071429
# ...       ...        ...        ...
# 9737   193581          1   4.000000
# 9738   193583          1   3.500000
# 9739   193585          1   3.500000
# 9740   193587          1   3.500000
# 9741   193609          1   4.000000
#
#                                           title  \
# 0                              Toy Story (1995)
# 1                                Jumanji (1995)
# 2                       Grumpier Old Men (1995)
# 3                      Waiting to Exhale (1995)
# 4            Father of the Bride Part II (1995)
# ...                                         ...
# 9737  Black Butler: Book of the Atlantic (2017)
# 9738               No Game No Life: Zero (2017)
# 9739                               Flint (2017)
# 9740        Bungo Stray Dogs: Dead Apple (2018)
# 9741        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 5 columns]

# %%
movies.insert(1, "allTags", "Empty")
movies
# Out:
#       movieId allTags  NumRating  AvgRating  \
# 0           1   Empty          9   3.920930
# 1           2   Empty         10   3.431818
# 2           3   Empty          9   3.259615
# 3           4   Empty          4   2.357143
# 4           5   Empty          9   3.071429
# ...       ...     ...        ...        ...
# 9737   193581   Empty          1   4.000000
# 9738   193583   Empty          1   3.500000
# 9739   193585   Empty          1   3.500000
# 9740   193587   Empty          1   3.500000
# 9741   193609   Empty          1   4.000000
#
#                                           title  \
# 0                              Toy Story (1995)
# 1                                Jumanji (1995)
# 2                       Grumpier Old Men (1995)
# 3                      Waiting to Exhale (1995)
# 4            Father of the Bride Part II (1995)
# ...                                         ...
# 9737  Black Butler: Book of the Atlantic (2017)
# 9738               No Game No Life: Zero (2017)
# 9739                               Flint (2017)
# 9740        Bungo Stray Dogs: Dead Apple (2018)
# 9741        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 6 columns]

# %%
tags[['tag']].where(tags[['movieId']].values == 5).stack().str.cat(sep='|')
# Out:
# 'pregnancy|remake'

# %%
def calculate_tags(row):
    return tags[['tag']].where(tags[['movieId']].values == row['movieId']).stack().str.cat(sep='|')

movies.apply(calculate_tags, axis=1)
# Out:
# 0                                    pixar|pixar|fun
# 1       fantasy|magic board game|Robin Williams|game
# 2                                          moldy|old
# 3
# 4                                   pregnancy|remake
#                             ...
# 9737
# 9738
# 9739
# 9740
# 9741
# Length: 9742, dtype: object

# %%
movies['allTags'] = movies.apply(calculate_tags, axis=1)
movies
# Out:
#       movieId                                       allTags  NumRating  \
# 0           1                               pixar|pixar|fun          9
# 1           2  fantasy|magic board game|Robin Williams|game         10
# 2           3                                     moldy|old          9
# 3           4                                                        4
# 4           5                              pregnancy|remake          9
# ...       ...                                           ...        ...
# 9737   193581                                                        1
# 9738   193583                                                        1
# 9739   193585                                                        1
# 9740   193587                                                        1
# 9741   193609                                                        1
#
#       AvgRating                                      title  \
# 0      3.920930                           Toy Story (1995)
# 1      3.431818                             Jumanji (1995)
# 2      3.259615                    Grumpier Old Men (1995)
# 3      2.357143                   Waiting to Exhale (1995)
# 4      3.071429         Father of the Bride Part II (1995)
# ...         ...                                        ...
# 9737   4.000000  Black Butler: Book of the Atlantic (2017)
# 9738   3.500000               No Game No Life: Zero (2017)
# 9739   3.500000                               Flint (2017)
# 9740   3.500000        Bungo Stray Dogs: Dead Apple (2018)
# 9741   4.000000        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 6 columns]

# %%
uniqueTags = tags['tag'].unique()

# %%
uniqueTags
# Out:
# array(['funny', 'Highly quotable', 'will ferrell', ..., 'gun fu',
#        'heroic bloodshed', 'Heroic Bloodshed'], dtype=object)

# %%
movies['NumRating'].max
# Out:
# <bound method Series.max of 0        9
# 1       10
# 2        9
# 3        4
# 4        9
#         ..
# 9737     1
# 9738     1
# 9739     1
# 9740     1
# 9741     1
# Name: NumRating, Length: 9742, dtype: int64>
